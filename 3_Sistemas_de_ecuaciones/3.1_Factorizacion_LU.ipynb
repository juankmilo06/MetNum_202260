# %% [markdown]
# # Factorización LU

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/caramirezs/MetNum_202210/blob/main/3_Sistemas_de_ecuaciones/3.1_Factorizacion_LU.ipynb)
